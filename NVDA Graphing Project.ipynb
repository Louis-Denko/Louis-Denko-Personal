# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import pandas as pd

# %%
# Data was downloaded from yahoo finance
nvda = pd.read_csv('NVDA.csv')
nvda['Date'] = pd.to_datetime(nvda.Date)
nvda.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-04-12  273.700012  274.679993  264.480011  264.950012  264.865082
# 1 2023-04-13  267.339996  268.869995  263.290009  264.630005  264.545166
# 2 2023-04-14  265.040009  268.829987  262.200012  267.579987  267.494202
# 3 2023-04-17  265.649994  270.059998  264.329987  270.019989  269.933411
# 4 2023-04-18  275.329987  281.100006  273.570007  276.670013  276.581299
#
#      Volume
# 0  44625900
# 1  35361500
# 2  39566000
# 3  32147100
# 4  60481200

# %%
fig, ax1 = plt.subplots(figsize=(15, 6))
ax1.plot(nvda['Date'], nvda['Close'], label='Close', color='blue')
ax1.set_xlabel('Date')
ax1.set_ylabel('Close Price', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.legend(loc='upper left')


ax2 = ax1.twinx()
ax2.bar(nvda['Date'], nvda['Volume'], label='Volume', color='orange', alpha=0.6, width=0.8)
ax2.set_ylabel('Volume', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')
ax2.legend(loc='upper right')


ax1.grid(True, which='major', linestyle='--', alpha=0.5)
plt.title('NVDA Close Prices and Volume Over Time')
plt.show()
